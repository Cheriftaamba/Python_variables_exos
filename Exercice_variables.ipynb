# %%
#Exercice 1: Poly-A
#Générez une chaîne de caractères représentant un brin d’ADN poly-A (c’est-à-dire qui ne contient que des bases A) de 20 bases de longueur, sans taper littéralement toutes les bases.

ADN_polyA = 'A' * 20
print(ADN_polyA)
# Out:
# AAAAAAAAAAAAAAAAAAAA

# %%
#Exercice 2: Poly-A et poly-GC
#Sur le modèle de l’exercice précédent, générez en une ligne de code un brin d’ADN poly-A (AAAA. . . ) de 20 bases suivi d’un poly-GC régulier (GCGCGC. . . ) de 40 bases.

ADN = ADN_polyA + "GC" * 20
print(ADN)
print(f"Longueur totale : {len(ADN)} bases")
# Out:
# AAAAAAAAAAAAAAAAAAAAGCGCGCGCGCGCGCGCGCGCGCGCGCGCGCGCGCGCGCGC
# Longueur totale : 60 bases

# %%
#Exercice 3 : Écriture formatée
#En utilisant l’écriture formatée, affichez en une seule ligne les variables a, b et c dont les valeurs sont respectivement la chaîne de caractères "salut", le nombre entier 102 et le float 10.318. La variable c sera affichée avec 2 décimales.

a = "salut"
b = 102
c = 10.318
Message = f"{a} je me nomme Shared, mon code est {b} et j'ai une note de {c:.2f}"
print(Message)
# Out:
# salut je me nomme Shared, mon code est 102 et j'ai une note de 10.32

# %%
#Exercice 4 :  Écriture formatée 2
#Créer une variable perc_GC = ((4500 + 2575)/14800)*100.
#Ensuite, affichez le contenu de la variable perc_GC à l’écran avec 0, 1, 2 puis 3 décimales sous forme arrondie en utilisant l’écriture formatée. On souhaite que le programme affiche la sortie suivante :
#Le pourcentage de GC est 48 %
#Le pourcentage de GC est 47.8 %
#Le pourcentage de GC est 47.80 %
#Le pourcentage de GC est 47.804 %

perc_GC = ((4500 + 2575)/14800) * 100

# Affichage avec différentes précisions
print(f"Le pourcentage de GC est {perc_GC:.0f} %")   # 0 décimale
print(f"Le pourcentage de GC est {perc_GC:.1f} %")   # 1 décimale
print(f"Le pourcentage de GC est {perc_GC:.2f} %")   # 2 décimales
print(f"Le pourcentage de GC est {perc_GC:.3f} %")   # 3 décimales
# Out:
# Le pourcentage de GC est 48 %
# Le pourcentage de GC est 47.8 %
# Le pourcentage de GC est 47.80 %
# Le pourcentage de GC est 47.804 %
